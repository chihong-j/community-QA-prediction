# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !p7zip -d './gdrive/My Drive/社群媒體分析/Project Data/pt.meta.stackoverflow.com.7z'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 13303940 bytes (13 MiB)
#
# Extracting archive: ./gdrive/My Drive/社群媒體分析/Project Data/pt.meta.stackoverflow.com.7z
# --
# Path = ./gdrive/My Drive/社群媒體分析/Project Data/pt.meta.stackoverflow.com.7z
# Type = 7z
# Physical Size = 13303940
# Headers Size = 305
# Method = BZip2
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Files: 8
# Size:       81735037
# Compressed: 13303940

# %%
import pandas as pd
badges = pd.read_xml("Badges.xml")
print(badges.head())
# Out:
#    Id  UserId            Name                     Date  Class  TagBased
# 0   1       1  Autobiographer  2013-12-10T23:58:56.157      3     False
# 1   2       2  Autobiographer  2013-12-10T23:58:56.157      3     False
# 2   3       3  Autobiographer  2013-12-10T23:58:56.157      3     False
# 3   4       6  Autobiographer  2013-12-10T23:58:56.157      3     False
# 4   5       7  Autobiographer  2013-12-10T23:58:56.157      3     False

# %%
users = pd.read_xml("Users.xml")
print(users.head())
# Out:
#    Id  Reputation             CreationDate   DisplayName  \
# 0  -1           1  2013-11-18T22:54:05.000    Comunidade
# 1   1         101  2013-11-19T00:55:41.000  Geoff Dalgas
# 2   2         101  2013-11-19T01:18:12.000   Nick Craver
# 3   3          99  2013-11-19T01:32:32.000       Sklivvz
# 4   4         101  2013-11-19T01:34:39.000   Jon Ericson
#
#             LastAccessDate                      WebsiteUrl  \
# 0  2013-11-18T22:56:40.867  http://meta.stackexchange.com/
# 1  2015-04-09T02:18:47.617        http://stackoverflow.com
# 2  2020-04-27T10:33:23.403    https://nickcraver.com/blog/
# 3  2019-10-04T19:18:46.047             https://sklivvz.com
# 4  2021-05-18T15:41:38.583          https://jlericson.com/
#
#                             Location  \
# 0                      no datacenter
# 1                      Corvallis, OR
# 2                  Winston-Salem, NC
# 3  Trento, Province of Trento, Italy
# 4                   Downtown Burbank
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Ei, eu sou um robô.</p>\n\n<p>Sou só um rob...    394      702
# 1  <p>Dev #2 who helped create Stack Overflow cur...     38        0
# 2  <p>I am a Principal Software Engineer at Micro...     26        0
# 3  <ul>\n<li>Stack Overflow Contributor since 200...     82        5
# 4  <p><a href="https://jlericson.com/2021/04/30/d...     53        7
#
#    DownVotes  AccountId                                ProfileImageUrl
# 0        344         -1                                           None
# 1          0          2  https://i.stack.imgur.com/nDllk.png?s=128&g=1
# 2          0       7598  https://i.stack.imgur.com/nGCYr.jpg?s=128&g=1
# 3          0       4623                                           None
# 4          0       1083                                           None

# %%
comments = pd.read_xml("Comments.xml")
print(comments.head())
# Out:
#    Id  PostId  Score                                               Text  \
# 0   1       1     12  Excelente! Rapaz, que coisa boa um SO em portu...
# 1   2       2      0  Gabe, apesar se solicitar perguntas, temos que...
# 2   3       1      0  O segundo subtítulo está escrito como: "O que ...
# 3   4       4      2  Também encontrei problemas ao dar um ponto neg...
# 4   5       2      0  @LuizAngioletti eu ganhei um bônus de 100 pela...
#
#               CreationDate  UserId ContentLicense UserDisplayName
# 0  2013-12-11T15:51:55.253    28.0   CC BY-SA 3.0            None
# 1  2013-12-11T15:52:47.600    35.0   CC BY-SA 3.0            None
# 2  2013-12-11T15:59:32.690    28.0   CC BY-SA 3.0            None
# 3  2013-12-11T16:00:48.317    54.0   CC BY-SA 3.0            None
# 4  2013-12-11T16:00:54.100    31.0   CC BY-SA 3.0            None

# %%
posts = pd.read_xml("Posts.xml")
print(posts.head())
# Out:
#   File "<string>", line 6765
# XMLSyntaxError: internal error: Huge input lookup, line 6765, column 947
